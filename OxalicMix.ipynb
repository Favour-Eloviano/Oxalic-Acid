# %%
# === 1. IMPORTS ===
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import joblib
import optuna

# Scikit-learn modules
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import make_scorer, r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import cross_validate, KFold
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.inspection import PartialDependenceDisplay
from sklearn.inspection import partial_dependence
from sklearn.metrics import make_scorer, r2_score, mean_absolute_error, mean_squared_error
from sklearn.base import BaseEstimator, RegressorMixin

# XGBoost Regressor
from xgboost import XGBRegressor
import xgboost as xgb

from mealpy.swarm_based import MRFO
from mealpy.utils.problem import Problem
from mealpy.utils.space import FloatVar
import time
from tqdm import tqdm

from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
from scipy.stats.mstats import winsorize

import shap
import itertools

# %%
data = pd.read_excel("Joyce Cleaned(Oxalic Mix Result).xlsx", 
                     sheet_name="Sheet1", 
                     usecols=["Potato Peel (g)", "Yam Peel (g)", "Banana peel (g)", "CONCENTRATION"], 
                     skiprows=2,     
                     nrows=17)

# %%
data
# Out:
#     Potato Peel (g)  Yam Peel (g)  Banana peel (g)  CONCENTRATION
# 0              2.50         10.00             2.50      16.000813
# 1              7.50          0.00             7.50       9.548173
# 2             15.00          0.00             0.00       8.943238
# 3              0.00          7.50             7.50      11.524294
# 4              6.25          2.50             6.25       9.427186
# 5              0.00         15.00             0.00      10.475740
# 6              2.50          2.50            10.00      10.637056
# 7              7.50          7.50             0.00      10.838701
# 8              0.00          7.50             7.50       8.418961
# 9              0.00          0.00            15.00       6.281524
# 10            10.00          2.50             2.50       9.265870
# 11             6.25          6.25             2.50      11.322649
# 12             0.00          0.00            15.00       6.281524
# 13            15.00          0.00             0.00       8.701264
# 14             0.00         15.00             0.00      10.354753
# 15             7.50          7.50             0.00       9.023896

# %%
# === 1. FEATURES & TARGET ===
X = data.drop(columns=['CONCENTRATION']).values
Y = data['CONCENTRATION'].values

# %%
SEED = 75
np.random.seed(SEED)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=SEED)

# %%
best_score = -np.inf
best_model = None

def objective(trial): 
    global best_score, best_model


    params = {
    "n_estimators": trial.suggest_int("n_estimators", 100, 50000, step=5),
    "max_depth": trial.suggest_int("max_depth", 1, 5),
    "learning_rate": trial.suggest_float("learning_rate", 0.5, 1.0, log=True),  # Keep it moderate
    "subsample": trial.suggest_float("subsample", 0.9, 1.0),
    "colsample_bytree": trial.suggest_float("colsample_bytree", 0.9, 1.0),
    "gamma": trial.suggest_float("gamma", 0.0, 0.3),
    "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 0.1),
    "reg_lambda": trial.suggest_float("reg_lambda", 1, 5.0),
    "min_child_weight": trial.suggest_int("min_child_weight", 3, 4),
    "max_delta_step": trial.suggest_int("max_delta_step", 0, 10),

}
    


    # Train the model
    model = XGBRegressor(
        **params,
        objective='reg:squarederror',
        random_state=SEED,
        n_jobs=-1,
        verbosity=0
    )

    kf = KFold(n_splits=5, shuffle=True, random_state=SEED)
    scores = cross_val_score(model, x_train, y_train, cv=kf, scoring="r2")
    mean_score = np.mean(scores)

    if mean_score > best_score:
        best_score = mean_score
        best_model = model
        model.fit(x_train, y_train)
    

    return mean_score

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)

print("Best CV R²:", best_score)
print("Best Parameters:", study.best_params)
# Out:
# [I 2025-08-22 08:22:19,472] A new study created in memory with name: no-name-51b26f29-558f-42e9-bc2f-437df07607f9
# [I 2025-08-22 08:22:48,014] Trial 0 finished with value: -4.178384804699731 and parameters: {'n_estimators': 10660, 'max_depth': 3, 'learning_rate': 0.5874584717601564, 'subsample': 0.9531849991259993, 'colsample_bytree': 0.9797930413534808, 'gamma': 0.25273257906958774, 'reg_alpha': 0.006207350556233593, 'reg_lambda': 3.175384878110131, 'min_child_weight': 4, 'max_delta_step': 4}. Best is trial 0 with value: -4.178384804699731.
# [I 2025-08-22 08:23:13,830] Trial 1 finished with value: -5.105599512269166 and parameters: {'n_estimators': 12110, 'max_depth': 4, 'learning_rate': 0.5854864845719274, 'subsample': 0.9145128969995644, 'colsample_bytree': 0.9686617599424838, 'gamma': 0.26050664731811635, 'reg_alpha': 0.045626041393351, 'reg_lambda': 3.6151302978964, 'min_child_weight': 3, 'max_delta_step': 5}. Best is trial 0 with value: -4.178384804699731.
# [I 2025-08-22 08:23:22,513] Trial 2 finished with value: -4.206943456209325 and parameters: {'n_estimators': 4585, 'max_depth': 2, 'learning_rate': 0.7639788705001073, 'subsample': 0.9500917675933535, 'colsample_bytree': 0.9747004629394799, 'gamma': 0.1160392037701248, 'reg_alpha': 0.05934704271357, 'reg_lambda': 1.7081467834924342, 'min_child_weight': 3, 'max_delta_step': 8}. Best is trial 0 with value: -4.178384804699731.
# [I 2025-08-22 08:24:07,994] Trial 3 finished with value: -4.8137974195253745 and parameters: {'n_estimators': 20510, 'max_depth': 5, 'learning_rate': 0.6955344445634671, 'subsample': 0.9580808127098751, 'colsample_bytree': 0.9096154106032142, 'gamma': 0.0463686070646843, 'reg_alpha': 0.07220748163686387, 'reg_lambda': 4.257840775457007, 'min_child_weight': 4, 'max_delta_step': 5}. Best is trial 0 with value: -4.178384804699731.
# [I 2025-08-22 08:25:28,288] Trial 4 finished with value: -10.491353200299333 and parameters: {'n_estimators': 37455, 'max_depth': 1, 'learning_rate': 0.8006332383666108, 'subsample': 0.9820747859672049, 'colsample_bytree': 0.9181524941016865, 'gamma': 0.0644506637603959, 'reg_alpha': 0.06168828434911952, 'reg_lambda': 4.857192976960706, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 0 with value: -4.178384804699731.
# [I 2025-08-22 08:27:17,800] Trial 5 finished with value: -7.959285302648342 and parameters: {'n_estimators': 45830, 'max_depth': 5, 'learning_rate': 0.5467065307371292, 'subsample': 0.9222420474428067, 'colsample_bytree': 0.915406398703941, 'gamma': 0.014414061394625853, 'reg_alpha': 0.024640274378935102, 'reg_lambda': 3.500569985095383, 'min_child_weight': 4, 'max_delta_step': 9}. Best is trial 0 with value: -4.178384804699731.
# [I 2025-08-22 08:28:28,329] Trial 6 finished with value: -5.5566680839919895 and parameters: {'n_estimators': 32335, 'max_depth': 3, 'learning_rate': 0.9535930373239812, 'subsample': 0.9360460998484269, 'colsample_bytree': 0.9666556442338377, 'gamma': 0.06968172461533952, 'reg_alpha': 0.053336321448438896, 'reg_lambda': 4.911836734998153, 'min_child_weight': 4, 'max_delta_step': 8}. Best is trial 0 with value: -4.178384804699731.
# [I 2025-08-22 08:28:33,040] Trial 7 finished with value: -3.987712303965587 and parameters: {'n_estimators': 1795, 'max_depth': 5, 'learning_rate': 0.9459752815873264, 'subsample': 0.9328388303349117, 'colsample_bytree': 0.9027766996260125, 'gamma': 0.12145569730278535, 'reg_alpha': 0.09292446877444283, 'reg_lambda': 3.269111767431365, 'min_child_weight': 3, 'max_delta_step': 3}. Best is trial 7 with value: -3.987712303965587.
# [I 2025-08-22 08:29:34,711] Trial 8 finished with value: -5.016378934407614 and parameters: {'n_estimators': 25385, 'max_depth': 5, 'learning_rate': 0.5553163907908667, 'subsample': 0.9665600161636015, 'colsample_bytree': 0.930974417797794, 'gamma': 0.005981787135278871, 'reg_alpha': 0.0959064930943266, 'reg_lambda': 4.018781908304435, 'min_child_weight': 4, 'max_delta_step': 6}. Best is trial 7 with value: -3.987712303965587.
# [I 2025-08-22 08:29:53,554] Trial 9 finished with value: -4.052683769544932 and parameters: {'n_estimators': 10080, 'max_depth': 5, 'learning_rate': 0.6311099484563997, 'subsample': 0.9485631524954355, 'colsample_bytree': 0.9044435577152908, 'gamma': 0.2203729124638711, 'reg_alpha': 0.010423945572318705, 'reg_lambda': 4.243773765754755, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 7 with value: -3.987712303965587.
# [I 2025-08-22 08:29:55,507] Trial 10 finished with value: -4.838773228107745 and parameters: {'n_estimators': 1010, 'max_depth': 4, 'learning_rate': 0.9993147652725634, 'subsample': 0.9041684540775221, 'colsample_bytree': 0.9426862704141383, 'gamma': 0.1684019377089897, 'reg_alpha': 0.09779084746226846, 'reg_lambda': 2.196493377286168, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 7 with value: -3.987712303965587.
# [I 2025-08-22 08:39:52,282] Trial 11 finished with value: -6.756525831014676 and parameters: {'n_estimators': 13515, 'max_depth': 4, 'learning_rate': 0.6600700039367403, 'subsample': 0.9329705572891366, 'colsample_bytree': 0.9000230400631989, 'gamma': 0.20197164340553939, 'reg_alpha': 0.0011257919305588948, 'reg_lambda': 2.578846588600958, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 7 with value: -3.987712303965587.
# [I 2025-08-22 08:39:54,430] Trial 12 finished with value: -4.5984797562767366 and parameters: {'n_estimators': 1015, 'max_depth': 5, 'learning_rate': 0.8612721697102694, 'subsample': 0.936290510367732, 'colsample_bytree': 0.9312643426343045, 'gamma': 0.21259528955380225, 'reg_alpha': 0.035296736739565286, 'reg_lambda': 2.7160647671409675, 'min_child_weight': 4, 'max_delta_step': 3}. Best is trial 7 with value: -3.987712303965587.
# [I 2025-08-22 08:40:39,626] Trial 13 finished with value: -1.5997086747879372 and parameters: {'n_estimators': 19555, 'max_depth': 4, 'learning_rate': 0.6252726332665051, 'subsample': 0.9984372365544991, 'colsample_bytree': 0.9498193137768023, 'gamma': 0.2997829642935031, 'reg_alpha': 0.07871739025025422, 'reg_lambda': 4.220372459788068, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:41:12,447] Trial 14 finished with value: -2.0943771660198314 and parameters: {'n_estimators': 19070, 'max_depth': 4, 'learning_rate': 0.5152660783094914, 'subsample': 0.986823111274961, 'colsample_bytree': 0.9921737469799679, 'gamma': 0.2949519221600789, 'reg_alpha': 0.07983661184636075, 'reg_lambda': 3.711714496523302, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:41:55,704] Trial 15 finished with value: -1.8340918681075173 and parameters: {'n_estimators': 21895, 'max_depth': 4, 'learning_rate': 0.5003107212540523, 'subsample': 0.9977775797428804, 'colsample_bytree': 0.992227855188908, 'gamma': 0.29872120495635635, 'reg_alpha': 0.07796298792282622, 'reg_lambda': 1.1459957170777146, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:42:56,992] Trial 16 finished with value: -2.007377400890785 and parameters: {'n_estimators': 29090, 'max_depth': 2, 'learning_rate': 0.5009679783539958, 'subsample': 0.9993594397594204, 'colsample_bytree': 0.9574126380210457, 'gamma': 0.29727205129793977, 'reg_alpha': 0.07568806991454193, 'reg_lambda': 1.1983257477488056, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:43:38,262] Trial 17 finished with value: -2.235425031911542 and parameters: {'n_estimators': 19845, 'max_depth': 3, 'learning_rate': 0.6314295109066168, 'subsample': 0.996933686154409, 'colsample_bytree': 0.9921523430734266, 'gamma': 0.2598603459570396, 'reg_alpha': 0.08466615360345503, 'reg_lambda': 1.1071358655287604, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:44:58,330] Trial 18 finished with value: -4.587014412266351 and parameters: {'n_estimators': 37450, 'max_depth': 4, 'learning_rate': 0.7514612857763002, 'subsample': 0.9752657064067505, 'colsample_bytree': 0.9497320724065275, 'gamma': 0.1634281434323836, 'reg_alpha': 0.06864331207407227, 'reg_lambda': 1.8124931605416088, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:45:49,361] Trial 19 finished with value: -3.9944240356348226 and parameters: {'n_estimators': 23680, 'max_depth': 2, 'learning_rate': 0.5466716385359148, 'subsample': 0.9873094864280398, 'colsample_bytree': 0.9988121235001876, 'gamma': 0.23891085038615845, 'reg_alpha': 0.08607668313011474, 'reg_lambda': 2.7674201249540857, 'min_child_weight': 3, 'max_delta_step': 3}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:46:24,205] Trial 20 finished with value: -5.727037396474655 and parameters: {'n_estimators': 15860, 'max_depth': 3, 'learning_rate': 0.6870957733199852, 'subsample': 0.9663583312852249, 'colsample_bytree': 0.9425092714037145, 'gamma': 0.29794253361104567, 'reg_alpha': 0.037803495550767396, 'reg_lambda': 2.1831907179170935, 'min_child_weight': 3, 'max_delta_step': 7}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:47:23,753] Trial 21 finished with value: -3.4483374665764686 and parameters: {'n_estimators': 28830, 'max_depth': 2, 'learning_rate': 0.5009425729023539, 'subsample': 0.9986381741354325, 'colsample_bytree': 0.9594533573008153, 'gamma': 0.2804529783296599, 'reg_alpha': 0.07529887408366728, 'reg_lambda': 1.0207945883491816, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:48:34,370] Trial 22 finished with value: -7.474647198280872 and parameters: {'n_estimators': 34160, 'max_depth': 1, 'learning_rate': 0.5002878479012155, 'subsample': 0.9997800525714482, 'colsample_bytree': 0.955964542502458, 'gamma': 0.27353615750927995, 'reg_alpha': 0.06223979671212649, 'reg_lambda': 1.431815264763663, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:49:29,359] Trial 23 finished with value: -3.376010626222746 and parameters: {'n_estimators': 26680, 'max_depth': 2, 'learning_rate': 0.5971776436732281, 'subsample': 0.9922899477173696, 'colsample_bytree': 0.9816473005081653, 'gamma': 0.23432487524177556, 'reg_alpha': 0.08541289884774131, 'reg_lambda': 1.3517212094998967, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:50:34,650] Trial 24 finished with value: -4.160115892296334 and parameters: {'n_estimators': 31195, 'max_depth': 3, 'learning_rate': 0.528217400603105, 'subsample': 0.9781119847304561, 'colsample_bytree': 0.9313011492323775, 'gamma': 0.18525429340654476, 'reg_alpha': 0.06900452150682752, 'reg_lambda': 2.1438645401359935, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:52:10,097] Trial 25 finished with value: -3.6094389848380373 and parameters: {'n_estimators': 44620, 'max_depth': 4, 'learning_rate': 0.5768269849488064, 'subsample': 0.9721747230064633, 'colsample_bytree': 0.9432275362475334, 'gamma': 0.2989194150818671, 'reg_alpha': 0.07640080832435711, 'reg_lambda': 1.6868841028249166, 'min_child_weight': 3, 'max_delta_step': 10}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:52:54,866] Trial 26 finished with value: -7.490994002638288 and parameters: {'n_estimators': 22025, 'max_depth': 1, 'learning_rate': 0.622172978063277, 'subsample': 0.9893859629060606, 'colsample_bytree': 0.9608457983385935, 'gamma': 0.27460659264070775, 'reg_alpha': 0.08964100340466098, 'reg_lambda': 4.431560300804202, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:53:31,853] Trial 27 finished with value: -3.504400927421983 and parameters: {'n_estimators': 17040, 'max_depth': 3, 'learning_rate': 0.5378918738923087, 'subsample': 0.9834588913027995, 'colsample_bytree': 0.9504642344091009, 'gamma': 0.23942469363230462, 'reg_alpha': 0.05292910184139489, 'reg_lambda': 1.3098744495405477, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:54:57,061] Trial 28 finished with value: -4.748213382652155 and parameters: {'n_estimators': 41500, 'max_depth': 2, 'learning_rate': 0.5628819282477062, 'subsample': 0.9926263972298809, 'colsample_bytree': 0.9836771976939142, 'gamma': 0.1173189574872234, 'reg_alpha': 0.08047687335530727, 'reg_lambda': 1.9658415776493727, 'min_child_weight': 3, 'max_delta_step': 4}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:55:56,573] Trial 29 finished with value: -4.236383357439502 and parameters: {'n_estimators': 28395, 'max_depth': 4, 'learning_rate': 0.6022432775688553, 'subsample': 0.9583728017929611, 'colsample_bytree': 0.9703649561317673, 'gamma': 0.25765441943831935, 'reg_alpha': 0.09963989943453397, 'reg_lambda': 3.032918385705911, 'min_child_weight': 3, 'max_delta_step': 4}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:56:18,905] Trial 30 finished with value: -3.53714910938062 and parameters: {'n_estimators': 9900, 'max_depth': 3, 'learning_rate': 0.5188732975298778, 'subsample': 0.9796101286273272, 'colsample_bytree': 0.9756827031788949, 'gamma': 0.2805511591123124, 'reg_alpha': 0.0655565047139956, 'reg_lambda': 1.4474200107712663, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:56:54,319] Trial 31 finished with value: -2.1450480616429606 and parameters: {'n_estimators': 17570, 'max_depth': 4, 'learning_rate': 0.516705611133478, 'subsample': 0.9890056998425206, 'colsample_bytree': 0.9902819698234806, 'gamma': 0.29797024140280803, 'reg_alpha': 0.07619524347603102, 'reg_lambda': 3.6699218740946815, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:57:44,220] Trial 32 finished with value: -1.634085966527294 and parameters: {'n_estimators': 23670, 'max_depth': 4, 'learning_rate': 0.5265449960520177, 'subsample': 0.9946845764066593, 'colsample_bytree': 0.9994981405759296, 'gamma': 0.2805843191463271, 'reg_alpha': 0.07721036887135624, 'reg_lambda': 3.9636957143469904, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:58:30,416] Trial 33 finished with value: -2.1078747282725616 and parameters: {'n_estimators': 23160, 'max_depth': 4, 'learning_rate': 0.574170013959945, 'subsample': 0.9952599441183245, 'colsample_bytree': 0.9986657777955413, 'gamma': 0.2507607707519754, 'reg_alpha': 0.057926134923618894, 'reg_lambda': 4.505704308707886, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 13 with value: -1.5997086747879372.
# [I 2025-08-22 08:59:07,243] Trial 34 finished with value: -1.484311447631017 and parameters: {'n_estimators': 13245, 'max_depth': 4, 'learning_rate': 0.5373344306407017, 'subsample': 0.9981744577442069, 'colsample_bytree': 0.9863375489503802, 'gamma': 0.2757755276048635, 'reg_alpha': 0.046431047390082116, 'reg_lambda': 3.977177783748525, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 34 with value: -1.484311447631017.
# [I 2025-08-22 08:59:21,075] Trial 35 finished with value: -2.884514891247819 and parameters: {'n_estimators': 6680, 'max_depth': 4, 'learning_rate': 0.6580651281908377, 'subsample': 0.9690871046322885, 'colsample_bytree': 0.9867981181428511, 'gamma': 0.27142271712420385, 'reg_alpha': 0.04334768555913645, 'reg_lambda': 3.930450118547702, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 34 with value: -1.484311447631017.
# [I 2025-08-22 08:59:51,082] Trial 36 finished with value: -2.762561770451125 and parameters: {'n_estimators': 13875, 'max_depth': 4, 'learning_rate': 0.5929216920441206, 'subsample': 0.9819986361013081, 'colsample_bytree': 0.9785928315177713, 'gamma': 0.22627782243066863, 'reg_alpha': 0.026273249318619782, 'reg_lambda': 4.664852327549379, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 34 with value: -1.484311447631017.
# [I 2025-08-22 09:00:08,839] Trial 37 finished with value: -2.0573510440512672 and parameters: {'n_estimators': 8085, 'max_depth': 5, 'learning_rate': 0.5330069269701996, 'subsample': 0.9918539668377936, 'colsample_bytree': 0.998693944382592, 'gamma': 0.19788980839624914, 'reg_alpha': 0.046008236830401165, 'reg_lambda': 3.904863509619962, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 34 with value: -1.484311447631017.
# [I 2025-08-22 09:00:39,056] Trial 38 finished with value: -4.347231046763996 and parameters: {'n_estimators': 15290, 'max_depth': 5, 'learning_rate': 0.7349860878209776, 'subsample': 0.9608882102213181, 'colsample_bytree': 0.9702511178423452, 'gamma': 0.25188356630473596, 'reg_alpha': 0.05907493666591489, 'reg_lambda': 3.3343520857107922, 'min_child_weight': 4, 'max_delta_step': 5}. Best is trial 34 with value: -1.484311447631017.
# [I 2025-08-22 09:01:21,851] Trial 39 finished with value: -3.209830432417408 and parameters: {'n_estimators': 20195, 'max_depth': 3, 'learning_rate': 0.5592642033024293, 'subsample': 0.9838971275144216, 'colsample_bytree': 0.9872918220387447, 'gamma': 0.2828248939343454, 'reg_alpha': 0.028379534936727534, 'reg_lambda': 4.141968244229032, 'min_child_weight': 3, 'max_delta_step': 3}. Best is trial 34 with value: -1.484311447631017.
# [I 2025-08-22 09:01:31,905] Trial 40 finished with value: -3.5695036005387677 and parameters: {'n_estimators': 4905, 'max_depth': 4, 'learning_rate': 0.8154205104212677, 'subsample': 0.9937729034151072, 'colsample_bytree': 0.994881380527009, 'gamma': 0.2631664168702027, 'reg_alpha': 0.016269957021974236, 'reg_lambda': 3.4568185147000072, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 34 with value: -1.484311447631017.
# [I 2025-08-22 09:02:39,262] Trial 41 finished with value: -1.4004378305462453 and parameters: {'n_estimators': 26390, 'max_depth': 3, 'learning_rate': 0.5090602691584325, 'subsample': 0.9987827314942008, 'colsample_bytree': 0.9229109253587827, 'gamma': 0.2860692347664094, 'reg_alpha': 0.07289322008145702, 'reg_lambda': 4.443311935266859, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 41 with value: -1.4004378305462453.
# [I 2025-08-22 09:03:32,203] Trial 42 finished with value: -2.0385496845896447 and parameters: {'n_estimators': 25480, 'max_depth': 3, 'learning_rate': 0.5444159382904693, 'subsample': 0.9994275890731567, 'colsample_bytree': 0.9661089577018241, 'gamma': 0.13718471648727668, 'reg_alpha': 0.09184765908486228, 'reg_lambda': 4.423436530086221, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 41 with value: -1.4004378305462453.
# [I 2025-08-22 09:04:16,639] Trial 43 finished with value: -2.7990155927385016 and parameters: {'n_estimators': 22090, 'max_depth': 4, 'learning_rate': 0.5257952934129668, 'subsample': 0.9940858354436684, 'colsample_bytree': 0.9198602159774155, 'gamma': 0.09876269953280128, 'reg_alpha': 0.06817997799998336, 'reg_lambda': 4.734819261199438, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 41 with value: -1.4004378305462453.
# [I 2025-08-22 09:04:42,286] Trial 44 finished with value: -1.881473538841309 and parameters: {'n_estimators': 12105, 'max_depth': 3, 'learning_rate': 0.5664908543540863, 'subsample': 0.9889039096662395, 'colsample_bytree': 0.912646782470546, 'gamma': 0.28413675278951256, 'reg_alpha': 0.08154245105890474, 'reg_lambda': 4.9636971001402355, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 41 with value: -1.4004378305462453.
# [I 2025-08-22 09:05:22,650] Trial 45 finished with value: -2.3574058899374415 and parameters: {'n_estimators': 18735, 'max_depth': 4, 'learning_rate': 0.5119361158935232, 'subsample': 0.9859960151397501, 'colsample_bytree': 0.9189492783528631, 'gamma': 0.26558737921769915, 'reg_alpha': 0.04902482283881576, 'reg_lambda': 4.127063513126251, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 41 with value: -1.4004378305462453.
# [I 2025-08-22 09:06:34,296] Trial 46 finished with value: -4.602622356675177 and parameters: {'n_estimators': 33230, 'max_depth': 5, 'learning_rate': 0.619893441365722, 'subsample': 0.9445834333000548, 'colsample_bytree': 0.925650469178166, 'gamma': 0.03660294997620854, 'reg_alpha': 0.07209297639970104, 'reg_lambda': 3.8173675942457486, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 41 with value: -1.4004378305462453.
# [I 2025-08-22 09:07:25,994] Trial 47 finished with value: -4.428337990403622 and parameters: {'n_estimators': 23970, 'max_depth': 4, 'learning_rate': 0.6540073499035608, 'subsample': 0.9015054878164265, 'colsample_bytree': 0.9858038826317201, 'gamma': 0.248381412013064, 'reg_alpha': 0.057300956806116216, 'reg_lambda': 4.262039697725286, 'min_child_weight': 3, 'max_delta_step': 6}. Best is trial 41 with value: -1.4004378305462453.
# [I 2025-08-22 09:08:21,085] Trial 48 finished with value: -4.973549714263362 and parameters: {'n_estimators': 26580, 'max_depth': 4, 'learning_rate': 0.5499205921079549, 'subsample': 0.9176690057105581, 'colsample_bytree': 0.9373944317440162, 'gamma': 0.21533460355008913, 'reg_alpha': 0.06302282214693668, 'reg_lambda': 4.6823781921861904, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 41 with value: -1.4004378305462453.
# [I 2025-08-22 09:09:08,186] Trial 49 finished with value: -3.556537273058963 and parameters: {'n_estimators': 21410, 'max_depth': 5, 'learning_rate': 0.7114887980627215, 'subsample': 0.97763533073457, 'colsample_bytree': 0.9773915460686031, 'gamma': 0.28573735738756606, 'reg_alpha': 0.08945679996393187, 'reg_lambda': 4.306291161065321, 'min_child_weight': 4, 'max_delta_step': 0}. Best is trial 41 with value: -1.4004378305462453.
# Best CV R²: -1.4004378305462453
# Best Parameters: {'n_estimators': 26390, 'max_depth': 3, 'learning_rate': 0.5090602691584325, 'subsample': 0.9987827314942008, 'colsample_bytree': 0.9229109253587827, 'gamma': 0.2860692347664094, 'reg_alpha': 0.07289322008145702, 'reg_lambda': 4.443311935266859, 'min_child_weight': 3, 'max_delta_step': 0}

# %%
# Predict
y_train_pred = best_model.predict(x_train)
y_test_pred = best_model.predict(x_test)

# R² Scores
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

print(f"Train R²: {train_r2:.4f}")
print(f"Test R²: {test_r2:.4f}")
# Out:
# Train R²: 0.8588
# Test R²: 0.8051

# %%
# Display best hyperparameters
best_params = study.best_params
print("Best Hyperparameters:", best_params)
print("Best validation R² Score from Optuna:", study.best_value)
# Out:
# Best Hyperparameters: {'n_estimators': 26390, 'max_depth': 3, 'learning_rate': 0.5090602691584325, 'subsample': 0.9987827314942008, 'colsample_bytree': 0.9229109253587827, 'gamma': 0.2860692347664094, 'reg_alpha': 0.07289322008145702, 'reg_lambda': 4.443311935266859, 'min_child_weight': 3, 'max_delta_step': 0}
# Best validation R² Score from Optuna: -1.4004378305462453

# %%
joblib.dump(best_model, "the_best_xgboost_oxalic_mix_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 joblib.dump(best_model, "the_best_xgboost_oxalic_mix_model.pkl")
#
# NameError: name 'best_model' is not defined

# %%
xgb_model = joblib.load('the_best_xgboost_oxalic_mix_model.pkl')
# Predict on the full dataset
y_pred_full = best_model.predict(X)

# Calculate R² score for the full dataset
r2_full = r2_score(Y, y_pred_full)
print(f'R² Score for the full dataset: {r2_full:.4f}')
# Out:
# R² Score for the full dataset: 0.8491

# %%
mse_full = mean_squared_error(Y, y_pred_full)
print(f'Mean Squared Error for the full dataset: {mse_full:.4f}')
# Out:
# Mean Squared Error for the full dataset: 0.7168

# %%
rmse_full = np.sqrt(mean_squared_error(Y, y_pred_full))
print(f'Root Mean Squared Error for the full dataset: {rmse_full:.4f}')
# Out:
# Root Mean Squared Error for the full dataset: 0.8466

# %%
# Calculate Average Absolute Deviation (AAD) for the full dataset
aad_full = np.mean(np.abs(Y.ravel() - y_pred_full))
print(f'Average Absolute Deviation (AAD) for the full dataset: {aad_full:.4f}')
# Out:
# Average Absolute Deviation (AAD) for the full dataset: 0.6802

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Make sure Y and y_pred_full are unscaled
n = len(Y)
rss = np.sum((Y.ravel() - y_pred_full) ** 2)

# Approximate parameter count
k = X.shape[1]  # or: k = best_model.get_params().get("n_estimators", X.shape[1])

# AIC formula
aic = n * np.log(rss / n) + 2 * k
print(f"AIC (approximate): {aic:.4f}")
# Out:
# AIC (approximate): 0.6719

# %%
# Create the dataframe
data_full = pd.DataFrame(
    X,
    columns=['Potato Peel (g)', 'Yam Peel (g)', 'Banana peel (g)']
    )		
)
data_full['Actual Oxalic Mix Concntration'] = Y
data_full['Predicted Oxalic Mix Concentration'] = y_pred_full 

data_full

# %% [markdown]
# **MRFO OPTIMIZATION**

# %%
xgb_model = joblib.load('the_best_xgboost_oxalic_mix_model.pkl')

# %%
from mealpy.swarm_based import MRFO
import numpy as np
from mealpy.utils.problem import Problem
from mealpy.utils.space import FloatVar
import time
from tqdm import tqdm
import joblib

# %%
# ======================
# Load your trained model
# ======================
xgb_model = joblib.load('the_best_xgboost_oxalic_mix_model.pkl')

# %%
# ======================
# Define Search Space (unscaled, 0–15 each)
# ======================
search_space = [
    FloatVar(0, 15),  # Potato Peel
    FloatVar(0, 15),  # Yam Peel
    FloatVar(0, 15),  # Banana Peel
]

# %%
# ======================
# MRFO Hyperparameter Grid
# ======================
mrfo_hyperparam_space = {
    "epoch": range(5, 51, 5),
    "pop_size": range(10, 101, 10),
    "somersault_range": [1.0, 1.5, 2.0]
}

# %%
# ======================
# Projection function (no zero values)
# ======================
def project_to_constraint(solution, eps=0.01):
    """
    Projects any [A,B,C] to satisfy:
    - 0 < A,B,C <= 15 (no zero)
    - A+B+C = 15
    """
    sol = np.clip(solution, eps, 15)  # ensure minimum > 0
    total = np.sum(sol)
    if total == 0:
        # fallback: split evenly above eps
        return np.array([5.0, 5.0, 5.0])
    # rescale so that the sum = 15
    sol = sol * (15.0 / total)
    return np.clip(sol, eps, 15)

# %%
# ======================
# Objective Function
# ======================
def objective_function(solution):
    sol = project_to_constraint(np.array(solution))
    X_input = sol.reshape(1, -1)
    y_pred = xgb_model.predict(X_input)[0]

    if y_pred < 0 or y_pred > 100:
        return 1e6  # penalize nonsense
    return -y_pred  # we want to maximize concentration

# %%
# ======================
# Custom Problem
# ======================
class CustomProblem(Problem):
    def __init__(self):
        super().__init__(bounds=search_space, minmax="min", log_to=None)

    def obj_func(self, solution):
        return objective_function(solution)

# %%
# ======================
# MRFO Tuning
# ======================
def tune_mrfo_hyperparameters():
    best_removal, best_inputs, best_hyperparams = -np.inf, None, None
    total_runs = (len(mrfo_hyperparam_space["epoch"]) *
                  len(mrfo_hyperparam_space["pop_size"]) *
                  len(mrfo_hyperparam_space["somersault_range"]))

    print(f"\n Starting MRFO optimization over {total_runs} combinations...\n")
    start_time = time.time()

    with tqdm(total=total_runs, desc="Optimizing", ncols=100) as pbar:
        for epoch in mrfo_hyperparam_space["epoch"]:
            for pop_size in mrfo_hyperparam_space["pop_size"]:
                for somersault_range in mrfo_hyperparam_space["somersault_range"]:
                    run_start = time.time()
                    problem = CustomProblem()
                    optimizer = MRFO.OriginalMRFO(epoch=epoch, pop_size=pop_size,
                                                  somersault_range=somersault_range)
                    result = optimizer.solve(problem, seed=93)
                    run_end = time.time()

                    predicted_removal = -result.target.fitness
                    if predicted_removal > best_removal:
                        best_removal = predicted_removal
                        best_hyperparams = (epoch, pop_size, somersault_range)
                        best_inputs = project_to_constraint(result.solution)

                    pbar.set_postfix({
                        "Epoch": epoch, "Pop": pop_size, "Som": somersault_range,
                        "Best Conc": f"{best_removal:.2f}",
                        "Time(s)": f"{run_end - run_start:.1f}"
                    })
                    pbar.update(1)

    print(f"\n Optimization completed in {time.time() - start_time:.2f} seconds.")
    return best_hyperparams, best_inputs, best_removal

# %%
# ======================
# Run Optimization
# ======================
best_hyperparameters, best_inputs, best_removal = tune_mrfo_hyperparameters()
# Out:
#  Starting MRFO optimization over 300 combinations...
# Optimizing: 100%|█| 300/300 [51:27<00:00, 10.29s/it, Epoch=50, Pop=100, Som=2, Best Conc=13.23, Time
#  Optimization completed in 3087.13 seconds.

# %%
# ======================
# Show Results
# ======================
print("\n🔹 Best MRFO Hyperparameters:")
print(f"  - Epoch: {best_hyperparameters[0]}")
print(f"  - Population Size: {best_hyperparameters[1]}")
print(f"  - Somersault Range: {best_hyperparameters[2]}")

print("\n🔹 Optimized Input Values (Peels in g):")
print(f"  - Potato Peel:  {best_inputs[0]:.2f}")
print(f"  - Yam Peel:     {best_inputs[1]:.2f}")
print(f"  - Banana Peel:  {best_inputs[2]:.2f}")
print(f"  - Sum:          {np.sum(best_inputs):.2f}")

print(f"\n🔹 Best Optimized Concentration: {best_removal:.2f}")
# Out:
# 🔹 Best MRFO Hyperparameters:
#   - Epoch: 5
#   - Population Size: 10
#   - Somersault Range: 2.0
#
# 🔹 Optimized Input Values (Peels in g):
#   - Potato Peel:  2.93
#   - Yam Peel:     12.07
#   - Banana Peel:  0.01
#   - Sum:          15.00
#
# 🔹 Best Optimized Concentration: 13.23

# %%
# ======================
# Define Search Space (unscaled, 0–15 each)
# ======================
search_space = [
    FloatVar(0.5, 15),  # Potato Peel
    FloatVar(0.5, 15),  # Yam Peel
    FloatVar(0.5, 15),  # Banana Peel
]

# %%
# ======================
# MRFO Hyperparameter Grid
# ======================
mrfo_hyperparam_space = {
    "epoch": range(5, 51, 5),
    "pop_size": range(10, 101, 10),
    "somersault_range": [1.0, 1.5, 2.0]
}

# %%
# ======================
# Projection function (no zero values)
# ======================
def project_to_constraint(solution, eps=0.05):
    """
    Projects any [A,B,C] to satisfy:
    - 0 < A,B,C <= 15 (no zero)
    - A+B+C = 15
    """
    sol = np.clip(solution, eps, 15)  # ensure minimum > 0
    total = np.sum(sol)
    if total == 0:
        # fallback: split evenly above eps
        return np.array([5.0, 5.0, 5.0])
    # rescale so that the sum = 15
    sol = sol * (15.0 / total)
    return np.clip(sol, eps, 15)

# %%
# ======================
# Objective Function
# ======================
def objective_function(solution):
    sol = project_to_constraint(np.array(solution))
    X_input = sol.reshape(1, -1)
    y_pred = xgb_model.predict(X_input)[0]

    if y_pred < 0 or y_pred > 100:
        return 1e6  # penalize nonsense
    return -y_pred  # we want to maximize concentration

# %%
# ======================
# Custom Problem
# ======================
class CustomProblem(Problem):
    def __init__(self):
        super().__init__(bounds=search_space, minmax="min", log_to=None)

    def obj_func(self, solution):
        return objective_function(solution)

# %%
# ======================
# MRFO Tuning
# ======================
def tune_mrfo_hyperparameters():
    best_removal, best_inputs, best_hyperparams = -np.inf, None, None
    total_runs = (len(mrfo_hyperparam_space["epoch"]) *
                  len(mrfo_hyperparam_space["pop_size"]) *
                  len(mrfo_hyperparam_space["somersault_range"]))

    print(f"\n Starting MRFO optimization over {total_runs} combinations...\n")
    start_time = time.time()

    with tqdm(total=total_runs, desc="Optimizing", ncols=100) as pbar:
        for epoch in mrfo_hyperparam_space["epoch"]:
            for pop_size in mrfo_hyperparam_space["pop_size"]:
                for somersault_range in mrfo_hyperparam_space["somersault_range"]:
                    run_start = time.time()
                    problem = CustomProblem()
                    optimizer = MRFO.OriginalMRFO(epoch=epoch, pop_size=pop_size,
                                                  somersault_range=somersault_range)
                    result = optimizer.solve(problem, seed=93)
                    run_end = time.time()

                    predicted_removal = -result.target.fitness
                    if predicted_removal > best_removal:
                        best_removal = predicted_removal
                        best_hyperparams = (epoch, pop_size, somersault_range)
                        best_inputs = project_to_constraint(result.solution)

                    pbar.set_postfix({
                        "Epoch": epoch, "Pop": pop_size, "Som": somersault_range,
                        "Best Conc": f"{best_removal:.2f}",
                        "Time(s)": f"{run_end - run_start:.1f}"
                    })
                    pbar.update(1)

    print(f"\n Optimization completed in {time.time() - start_time:.2f} seconds.")
    return best_hyperparams, best_inputs, best_removal

# %%
# ======================
# Run Optimization
# ======================
best_hyperparameters, best_inputs, best_removal = tune_mrfo_hyperparameters()
# Out:
#  Starting MRFO optimization over 300 combinations...
# Optimizing: 100%|█| 300/300 [1:02:57<00:00, 12.59s/it, Epoch=50, Pop=100, Som=2, Best Conc=13.23, Ti
#  Optimization completed in 3777.64 seconds.

# %%
# ======================
# Show Results
# ======================
print("\n🔹 Best MRFO Hyperparameters:")
print(f"  - Epoch: {best_hyperparameters[0]}")
print(f"  - Population Size: {best_hyperparameters[1]}")
print(f"  - Somersault Range: {best_hyperparameters[2]}")

print("\n🔹 Optimized Input Values (Peels in g):")
print(f"  - Potato Peel:  {best_inputs[0]:.2f}")
print(f"  - Yam Peel:     {best_inputs[1]:.2f}")
print(f"  - Banana Peel:  {best_inputs[2]:.2f}")
print(f"  - Sum:          {np.sum(best_inputs):.2f}")

print(f"\n🔹 Best Optimized Concentration: {best_removal:.2f}")
# Out:
# 🔹 Best MRFO Hyperparameters:
#   - Epoch: 5
#   - Population Size: 10
#   - Somersault Range: 2.0
#
# 🔹 Optimized Input Values (Peels in g):
#   - Potato Peel:  3.23
#   - Yam Peel:     11.39
#   - Banana Peel:  0.38
#   - Sum:          15.00
#
# 🔹 Best Optimized Concentration: 13.23

# %%
# === 1. IMPORTS ===
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import joblib
import optuna

# Scikit-learn modules
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import make_scorer, r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import cross_validate, KFold
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.inspection import PartialDependenceDisplay
from sklearn.inspection import partial_dependence
from sklearn.metrics import make_scorer, r2_score, mean_absolute_error, mean_squared_error
from sklearn.base import BaseEstimator, RegressorMixin

# XGBoost Regressor
from xgboost import XGBRegressor
import xgboost as xgb

from mealpy.swarm_based import MRFO
from mealpy.utils.problem import Problem
from mealpy.utils.space import FloatVar
import time
from tqdm import tqdm

from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
from scipy.stats.mstats import winsorize

import shap
import itertools

# %%
xgb_model = joblib.load('the_best_xgboost_oxalic_mix_model.pkl')

# %%
# Example: load Sheet1, only rows 2–11 (Excel rows, meaning index 1–10 in Python)
data = pd.read_excel("Joyce Cleaned(Oxalic Mix Result).xlsx", 
                     sheet_name="Sheet1", 
                     usecols=["Potato Peel (g)", "Yam Peel (g)", "Banana peel (g)", "CONCENTRATION"], 
                     skiprows=2,    # skip the first row
                     nrows=17)      # read the next 10 rows#

# %%
data
# Out:
#     Potato Peel (g)  Yam Peel (g)  Banana peel (g)  CONCENTRATION
# 0              2.50         10.00             2.50      16.000813
# 1              7.50          0.00             7.50       9.548173
# 2             15.00          0.00             0.00       8.943238
# 3              0.00          7.50             7.50      11.524294
# 4              6.25          2.50             6.25       9.427186
# 5              0.00         15.00             0.00      10.475740
# 6              2.50          2.50            10.00      10.637056
# 7              7.50          7.50             0.00      10.838701
# 8              0.00          7.50             7.50       8.418961
# 9              0.00          0.00            15.00       6.281524
# 10            10.00          2.50             2.50       9.265870
# 11             6.25          6.25             2.50      11.322649
# 12             0.00          0.00            15.00       6.281524
# 13            15.00          0.00             0.00       8.701264
# 14             0.00         15.00             0.00      10.354753
# 15             7.50          7.50             0.00       9.023896

# %%
# === 1. FEATURES & TARGET ===
X = data.drop(columns=['CONCENTRATION']).values
Y = data['CONCENTRATION'].values

# %%
# Predict on the full dataset
y_pred_full = xgb_model.predict(X)

# Calculate R² score for the full dataset
r2_full = r2_score(Y, y_pred_full)
print(f'R² Score for the full dataset: {r2_full:.4f}')
# Out:
# R² Score for the full dataset: 0.8491

# %%
mse_full = mean_squared_error(Y, y_pred_full)
print(f'Mean Squared Error for the full dataset: {mse_full:.4f}')
# Out:
# Mean Squared Error for the full dataset: 0.7168

# %%
rmse_full = np.sqrt(mean_squared_error(Y, y_pred_full))
print(f'Root Mean Squared Error for the full dataset: {rmse_full:.4f}')
# Out:
# Root Mean Squared Error for the full dataset: 0.8466

# %%
# Calculate Average Absolute Deviation (AAD) for the full dataset
aad_full = np.mean(np.abs(Y - y_pred_full))
print(f'Average Absolute Deviation (AAD) for the full dataset: {aad_full:.4f}')
# Out:
# Average Absolute Deviation (AAD) for the full dataset: 0.6802

# %%
# Calculate AIC for the full dataset
n = len(Y)
residual_sum_of_squares = np.sum((Y - y_pred_full) ** 2)
k = len(xgb_model.get_params())  # number of model parameters

aic_full = n * np.log(residual_sum_of_squares / n) + 2 * k
print(f'AIC for the full dataset: {aic_full:.4f}')
# Out:
# AIC for the full dataset: 74.6719

# %%
# Create the dataframe
data_full = pd.DataFrame(
    X,
    columns=['Potato Peel (g)', 'Yam Peel (g)', 'Banana peel (g)']
    )		

data_full['Actual Oxalic Mix Concntration'] = Y
data_full['Predicted Oxalic Mix Concentration'] = y_pred_full 

data_full
# Out:
#     Potato Peel (g)  Yam Peel (g)  Banana peel (g)  \
# 0              2.50         10.00             2.50
# 1              7.50          0.00             7.50
# 2             15.00          0.00             0.00
# 3              0.00          7.50             7.50
# 4              6.25          2.50             6.25
# 5              0.00         15.00             0.00
# 6              2.50          2.50            10.00
# 7              7.50          7.50             0.00
# 8              0.00          7.50             7.50
# 9              0.00          0.00            15.00
# 10            10.00          2.50             2.50
# 11             6.25          6.25             2.50
# 12             0.00          0.00            15.00
# 13            15.00          0.00             0.00
# 14             0.00         15.00             0.00
# 15             7.50          7.50             0.00
#
#     Actual Oxalic Mix Concntration  Predicted Oxalic Mix Concentration
# 0                        16.000813                           15.214657
# 1                         9.548173                            9.570955
# 2                         8.943238                            8.409145
# 3                        11.524294                            9.374676
# 4                         9.427186                           10.721840
# 5                        10.475740                           10.706541
# 6                        10.637056                           10.721840
# 7                        10.838701                           10.063129
# 8                         8.418961                            9.374676
# 9                         6.281524                            6.896242
# 10                        9.265870                            9.800936
# 11                       11.322649                           10.721840
# 12                        6.281524                            6.896242
# 13                        8.701264                            8.409145
# 14                       10.354753                           10.706541
# 15                        9.023896                           10.063129
